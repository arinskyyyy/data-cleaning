# %% [markdown]
# <a href="https://colab.research.google.com/github/arinskyyyy/data-cleaning/blob/main/cleaning_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import userdata
import os

# 1. Grab your secret token
try:
    token = userdata.get('GITHUB_TOKEN')
except:
    print("Error: Did you name your secret 'GITHUB_TOKEN' and toggle 'Notebook access' on?")

# 2. Define your details
username = "arinskyyyy"
repo = "data-cleaning"

# 3. Formulate the URL
# We use this format to bypass the 'remote_url' variable error
remote_url = f"https://{token}@github.com/{username}/{repo}.git"

# 4. Execute the Git commands
# !git remote remove origin 2>/dev/null  # Removes old remote if it exists
# !git remote add origin {remote_url}
# !git branch -M main

print("Pushing to GitHub...")
# !git push -u origin main
# Out:
# Pushing to GitHub...
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date

# %% [markdown]
# To confirm the files currently in your working directory (which is the root of your `data-cleaning` repository), you can run the following command:

# %%
# List all files and directories in the current directory
# !ls -a
# Out:
# .  ..  .config	drive  .git  .gitignore  sample_data

# %% [markdown]
# After verifying your files, please re-run cell `owO3w-9oknZ_`. This cell will ensure all new and modified files (respecting your `.gitignore`) are staged, committed, and pushed to your `data-cleaning` repository on GitHub.

# %%
import os

# Create a .gitignore file to exclude unnecessary Colab and Google Drive files
# This helps prevent errors with unsupported file types and keeps your repo clean.
with open('.gitignore', 'w') as f:
    f.write('/.config/\n')
    f.write('/drive/\n')
    f.write('/sample_data/\n')
    f.write('*.gdoc\n')
    f.write('*.gsheet\n')
    f.write('*.gslides\n')
    f.write('*.ipynb_checkpoints/\n')
    f.write('__pycache__/\n')

# Configure Git user name and email (important for commits)
# !git config --global user.email "arinskyyyy@gmail.com"
# !git config --global user.name "arinskyyyy"

# Remove existing origin if it exists to avoid errors when re-adding
# !git remote remove origin 2>/dev/null
# Add the remote origin using the pre-defined remote_url
# !git remote add origin {remote_url}

# Reset the staging area to clear any problematic entries from previous failed attempts
# !git reset

# Stage all changes (add all files and folders to the staging area)
# The .gitignore file will now prevent unsupported files from being added.
# !git add .

# Commit the staged changes
# Replace "Initial commit" with a meaningful message for your changes.
# !git commit -m "Initial commit"

# Set the branch name to 'main' (common practice now)
# !git branch -M main

# Push the changes to the remote repository
print("Pushing to GitHub...")
# !git push -u origin main

print("If prompted, enter your GitHub username and Personal Access Token (PAT).")
# Out:
# On branch main
# nothing to commit, working tree clean
# Pushing to GitHub...
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
# If prompted, enter your GitHub username and Personal Access Token (PAT).
